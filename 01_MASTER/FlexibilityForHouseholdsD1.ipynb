# %%
import pandas as pd


df_consum = pd.read_csv('data_hourly.csv')
df_experiment_days = pd.read_csv('experiment_days.csv')
df_price_signals = pd.read_csv('price_signals.csv')

# %%
print(df_consum.head())
print(df_consum.shape)

print(df_experiment_days.head())
print(df_experiment_days.shape)

print(df_price_signals.head())
print(df_price_signals.shape)


oneEntry = df_consum.loc[df_consum['ID'] == 'Exp_2']

print('En innføring:')
print(oneEntry.shape)

iteration_count = 0
count = 0

unique_ids = df_consum["ID"].unique()

for id, group in df_consum.groupby("ID"):
    if iteration_count >= 1:  # Stop after 10 iterations
        break
    
    print(f"Temperatures for ID = {id}:")
    avg_temp=0
    
    for temp in group["Temperature"]:
        avg_temp += temp
        count += 1
        
    avg_temp = avg_temp/count
    print(avg_temp)
    
    #Filter entries for the date 2020-02-01
    date_filter = group[group["Date"] == "2020-02-01"]
    
    # Print all entries for 2020-02-01
    print(f"Entries for ID = {id} on 2020-02-01:")
    for index, row in date_filter.iterrows():
        print(row)
    

    
    iteration_count += 1
    
min_temperatures = df_consum.groupby("ID")["Temperature"].min()

print("Minimum temperatures for each ID:")
print(min_temperatures)

#number of unique IDs is equal to the number of households
num_unique_ids = df_consum['ID'].nunique()
print(num_unique_ids)
# Out:
#        ID                  From        Date  Hour Participation_Phase  \
# 0  Exp_43  2020-02-01T00:00:00Z  2020-02-01     1             Phase_1
# 1  Exp_43  2020-02-01T01:00:00Z  2020-02-01     2             Phase_1
# 2  Exp_43  2020-02-01T02:00:00Z  2020-02-01     3             Phase_1
# 3  Exp_43  2020-02-01T03:00:00Z  2020-02-01     4             Phase_1
# 4  Exp_43  2020-02-01T04:00:00Z  2020-02-01     5             Phase_1
#
#    Demand_kWh Price_signal  Experiment_price_NOK_kWh  Temperature  \
# 0       0.348          NaN                       NaN          7.6
# 1       0.589          NaN                       NaN          8.2
# 2       0.358          NaN                       NaN          8.4
# 3       0.582          NaN                       NaN          8.4
# 4       0.364          NaN                       NaN          8.2
#
#    Temperature24  Temperature48  Temperature72
# 0            6.1            5.0            4.4
# 1            6.2            5.1            4.4
# 2            6.3            5.3            4.5
# 3            6.4            5.4            4.5
# 4            6.5            5.5            4.6
# (13515600, 12)
#   Participation_Phase Price_signal        Date Group
# 0             Phase_1         A_10  2020-02-13    H1
# 1             Phase_1         A_10  2020-03-02    H1
# 2             Phase_1          A_5  2020-02-14    H1
# 3             Phase_1          A_5  2020-03-03    H1
# 4             Phase_1         B_10  2020-03-04    H1
# (267, 4)
#   Price_signal Price_profile Price_level  Hour  Experiment_price_NOK_kWh
# 0         A_10             A          10     1                      1.00
# 1         A_10             A          10     2                      0.99
# 2         A_10             A          10     3                      0.95
# 3         A_10             A          10     4                      0.95
# 4         A_10             A          10     5                      0.96
# (336, 5)
# En innføring:
# (4584, 12)
# Temperatures for ID = Exp_1:
# 3.255802792321112
# Entries for ID = Exp_1 on 2020-02-01:
# ID                                         Exp_1
# From                        2020-02-01T00:00:00Z
# Date                                  2020-02-01
# Hour                                           1
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.393
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  7.6
# Temperature24                                6.1
# Temperature48                                5.0
# Temperature72                                4.4
# Name: 192600, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T01:00:00Z
# Date                                  2020-02-01
# Hour                                           2
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.056
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  8.2
# Temperature24                                6.2
# Temperature48                                5.1
# Temperature72                                4.4
# Name: 192601, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T02:00:00Z
# Date                                  2020-02-01
# Hour                                           3
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.258
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  8.4
# Temperature24                                6.3
# Temperature48                                5.3
# Temperature72                                4.5
# Name: 192602, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T03:00:00Z
# Date                                  2020-02-01
# Hour                                           4
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.535
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  8.4
# Temperature24                                6.4
# Temperature48                                5.4
# Temperature72                                4.5
# Name: 192603, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T04:00:00Z
# Date                                  2020-02-01
# Hour                                           5
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.042
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  8.2
# Temperature24                                6.5
# Temperature48                                5.5
# Temperature72                                4.6
# Name: 192604, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T05:00:00Z
# Date                                  2020-02-01
# Hour                                           6
# Participation_Phase                      Phase_1
# Demand_kWh                                 1.947
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  8.0
# Temperature24                                6.6
# Temperature48                                5.6
# Temperature72                                4.7
# Name: 192605, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T06:00:00Z
# Date                                  2020-02-01
# Hour                                           7
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.112
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  8.1
# Temperature24                                6.7
# Temperature48                                5.7
# Temperature72                                4.7
# Name: 192606, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T07:00:00Z
# Date                                  2020-02-01
# Hour                                           8
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.796
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  8.1
# Temperature24                                6.8
# Temperature48                                5.8
# Temperature72                                4.8
# Name: 192607, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T08:00:00Z
# Date                                  2020-02-01
# Hour                                           9
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.267
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  7.6
# Temperature24                                6.9
# Temperature48                                5.9
# Temperature72                                4.9
# Name: 192608, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T09:00:00Z
# Date                                  2020-02-01
# Hour                                          10
# Participation_Phase                      Phase_1
# Demand_kWh                                 3.329
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  7.4
# Temperature24                                6.9
# Temperature48                                6.0
# Temperature72                                5.0
# Name: 192609, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T10:00:00Z
# Date                                  2020-02-01
# Hour                                          11
# Participation_Phase                      Phase_1
# Demand_kWh                                  2.64
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  7.4
# Temperature24                                6.9
# Temperature48                                6.0
# Temperature72                                5.0
# Name: 192610, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T11:00:00Z
# Date                                  2020-02-01
# Hour                                          12
# Participation_Phase                      Phase_1
# Demand_kWh                                 3.444
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  7.2
# Temperature24                                7.0
# Temperature48                                6.1
# Temperature72                                5.1
# Name: 192611, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T12:00:00Z
# Date                                  2020-02-01
# Hour                                          13
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.588
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  7.3
# Temperature24                                7.1
# Temperature48                                6.2
# Temperature72                                5.2
# Name: 192612, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T13:00:00Z
# Date                                  2020-02-01
# Hour                                          14
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.179
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  6.0
# Temperature24                                7.1
# Temperature48                                6.2
# Temperature72                                5.3
# Name: 192613, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T14:00:00Z
# Date                                  2020-02-01
# Hour                                          15
# Participation_Phase                      Phase_1
# Demand_kWh                                  2.18
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  3.8
# Temperature24                                7.1
# Temperature48                                6.3
# Temperature72                                5.3
# Name: 192614, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T15:00:00Z
# Date                                  2020-02-01
# Hour                                          16
# Participation_Phase                      Phase_1
# Demand_kWh                                 3.173
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  3.2
# Temperature24                                7.0
# Temperature48                                6.3
# Temperature72                                5.4
# Name: 192615, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T16:00:00Z
# Date                                  2020-02-01
# Hour                                          17
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.368
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  3.2
# Temperature24                                6.9
# Temperature48                                6.3
# Temperature72                                5.4
# Name: 192616, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T17:00:00Z
# Date                                  2020-02-01
# Hour                                          18
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.492
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  3.0
# Temperature24                                6.8
# Temperature48                                6.2
# Temperature72                                5.3
# Name: 192617, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T18:00:00Z
# Date                                  2020-02-01
# Hour                                          19
# Participation_Phase                      Phase_1
# Demand_kWh                                 4.129
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  2.8
# Temperature24                                6.6
# Temperature48                                6.2
# Temperature72                                5.3
# Name: 192618, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T19:00:00Z
# Date                                  2020-02-01
# Hour                                          20
# Participation_Phase                      Phase_1
# Demand_kWh                                 3.645
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  2.9
# Temperature24                                6.5
# Temperature48                                6.2
# Temperature72                                5.3
# Name: 192619, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T20:00:00Z
# Date                                  2020-02-01
# Hour                                          21
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.431
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  3.2
# Temperature24                                6.4
# Temperature48                                6.1
# Temperature72                                5.3
# Name: 192620, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T21:00:00Z
# Date                                  2020-02-01
# Hour                                          22
# Participation_Phase                      Phase_1
# Demand_kWh                                 2.634
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  2.9
# Temperature24                                6.3
# Temperature48                                6.1
# Temperature72                                5.3
# Name: 192621, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T22:00:00Z
# Date                                  2020-02-01
# Hour                                          23
# Participation_Phase                      Phase_1
# Demand_kWh                                 3.304
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  2.8
# Temperature24                                6.2
# Temperature48                                6.1
# Temperature72                                5.3
# Name: 192622, dtype: object
# ID                                         Exp_1
# From                        2020-02-01T23:00:00Z
# Date                                  2020-02-01
# Hour                                          24
# Participation_Phase                      Phase_1
# Demand_kWh                                 3.189
# Price_signal                                 NaN
# Experiment_price_NOK_kWh                     NaN
# Temperature                                  2.9
# Temperature24                                6.0
# Temperature48                                6.0
# Temperature72                                5.3
# Name: 192623, dtype: object
# Minimum temperatures for each ID:
# ID
# Exp_1     -11.4
# Exp_10    -14.2
# Exp_100   -14.2
# Exp_101   -14.2
# Exp_102   -14.2
#            ...
# Exp_95    -14.2
# Exp_96    -14.2
# Exp_97    -14.2
# Exp_98    -14.2
# Exp_99    -14.2
# Name: Temperature, Length: 4429, dtype: float64
# 4429

# %%
#TODO

#1. Calculate pricerespons, this gives an estimate of flexibility.
#2. A value representing flexibility is included in the survey data as a target value
#3. Check correlation between target value and the features(input variables)

#BONUS

#Clean the survey dataset
#Check for different ML methods
#Do the same for D2 and compare the results


#Notes meeting 06.02
